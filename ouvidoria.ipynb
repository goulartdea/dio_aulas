# %% [markdown]
# <a href="https://colab.research.google.com/github/goulartdea/dio_aulas/blob/main/ouvidoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prefeitura de POA - Dados Abertos - Ouvidoria

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ouvidoria = pd.read_csv('/content/ouvidoria.csv', sep=';')

# %%
ouvidoria
# Out:
#                  data_extracao     protocolo                 descricao  \
# 0      2023-10-01 00:00:00.000  000039-19-66                  FINANÇAS
# 1      2023-10-01 00:00:00.000  000040-19-15                  FINANÇAS
# 2      2023-10-01 00:00:00.000  000049-19-06  INFRAESTRUTURA URBANISMO
# 3      2023-10-01 00:00:00.000  000069-19-06  INFRAESTRUTURA URBANISMO
# 4      2023-10-01 00:00:00.000  000076-19-82                OUTRO TEMA
# ...                        ...           ...                       ...
# 28780  2023-10-01 00:00:00.000  063601-23-35                       NaN
# 28781  2023-10-01 00:00:00.000  063605-23-56                       NaN
# 28782  2023-10-01 00:00:00.000  063608-23-10                       NaN
# 28783  2023-10-01 00:00:00.000  063623-23-31                       NaN
# 28784  2023-10-01 00:00:00.000  063632-23-23                       NaN
#
#         sigla statussolicitacao             dataregistro  \
# ...

# %%
ouvidoria.isnull().sum()

# %%
ouvidoria.info()

# %%
ouvidoria.columns.values

# %% [markdown]
# Filtragem de dados

# %%
ouvidoria.describe()

# %% [markdown]
# Verificação de quantas denuncias estão pendentes no canal da ouvidoria da cidade de Porto Alegre, RS

# %%
#Seleção na coluna "status" somente as denuncias que estão como "em avaliação", que considerei como pendentes
selecao_ouvidoria = ouvidoria[ouvidoria['statussolicitacao'].str.contains('EM_AVALIACAO', case=False)]

# %%
selecao_ouvidoria
# Out:
#                  data_extracao     protocolo            descricao sigla  \
# 27274  2023-10-01 00:00:00.000  059564-23-82           SANEAMENTO   NaN
# 28217  2023-10-01 00:00:00.000  063472-23-35  AUXÍLIO AO SERVIDOR   NaN
# 28223  2023-10-01 00:00:00.000  063549-23-19                  NaN   NaN
# 28225  2023-10-01 00:00:00.000  063571-23-16                  NaN   NaN
# 28226  2023-10-01 00:00:00.000  063578-23-01                  NaN   NaN
# 28227  2023-10-01 00:00:00.000  063581-23-66                  NaN   NaN
# 28228  2023-10-01 00:00:00.000  063615-23-06                  NaN   NaN
# 28229  2023-10-01 00:00:00.000  063624-23-99                  NaN   NaN
# 28230  2023-10-01 00:00:00.000  063635-23-96                  NaN   NaN
# 28401  2023-10-01 00:00:00.000  063506-23-75           SANEAMENTO   NaN
# 28405  2023-10-01 00:00:00.000  063541-23-86                  NaN   NaN
# 28407  2023-10-01 00:00:00.000  063550-23-78                  NaN   NaN
# ...

# %%
# Quantidade de denúncias pendentes no momento da extração dos dados: 52 aguardando resposta
selecao_ouvidoria.shape
# Out:
# (52, 9)

# %% [markdown]
# Transformando um dataframe em arquivo csv

# %%
selecao_ouvidoria.to_csv('pendencias_ouvidoria', index=False)
